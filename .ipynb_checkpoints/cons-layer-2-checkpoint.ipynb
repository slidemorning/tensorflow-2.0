# %% [markdown]
# # Layer Explaination

# %% [markdown]
# ## Feature Extraction (Convolution)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202020-10-06%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.04.40.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202020-10-06%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%201.04.40.png)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from tensorflow.keras import datasets

(X_train, y_train), (X_test, y_test) = datasets.mnist.load_data()

# %%
image = X_train[0]

# %%
image.shape
# Out:
# (28, 28)

# %% [markdown]
# ### Reshape For Layer
# * [Batch, Height, Width, Channel]
# * tf.newaxis

# %%
image = image[tf.newaxis, ..., tf.newaxis]
image.shape
# Out:
# (1, 28, 28, 1)

# %% [markdown]
# ### Convolutional Layer
# * tf.keras.layers.Conv2D

# %%
tf.keras.layers.Conv2D(filters=3, kernel_size=(3, 3), strides=(1, 1), padding='VALID', activation='relu')
# kernel_size=3 (==) kernel_size=(3, 3)

# %%
image = tf.cast(image, dtype=tf.float32)

# %%
layer = tf.keras.layers.Conv2D(filters=3, kernel_size=3, strides=(1, 1), padding='SAME')
# not exist activation function

# %%
output = layer(image)

# %% [markdown]
# ### Weight
# * {layer}.get_weights()

# %%
weight = layer.get_weights()[0]

# %%
plt.figure(figsize=(15, 5))
plt.subplot(131)
plt.hist(output.numpy().ravel(), range=[-2, 2])
plt.ylim(0, 500)
plt.subplot(132)
plt.title(weight.shape)
plt.imshow(weight[:, :, 0, 0], 'gray')
plt.subplot(133)
plt.title(output.shape)
plt.imshow(output[0, :, :, 0], 'gray')
plt.colorbar()
plt.show()

# %% [markdown]
# ### Activation Function (ReLU)
# * tf.keras.layers.ReLU()

# %%
layer = tf.keras.layers.ReLU()
output = layer(output)

# %%
plt.figure(figsize=(15, 5))
plt.subplot(131)
plt.hist(output.numpy().ravel(), range=[-2, 2])
plt.ylim(0, 500)
plt.subplot(132)
plt.title(output.shape)
plt.imshow(output[0, :, :, 0], 'gray')
plt.colorbar()
plt.show()

# %% [markdown]
# ### Pooling Layrer
# * tf.keras.layers.MaxPool2D

# %%
tf.keras.layers.MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='SAME')

# %%
layer = tf.keras.layers.MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='SAME')
output = layer(output)

# %%
plt.figure(figsize=(15, 5))
plt.subplot(131)
plt.hist(output.numpy().ravel(), range=[-2,2])
plt.ylim(0, 500)
plt.subplot(132)
plt.title(output.shape)
plt.imshow(output[0, :, :, 0], 'gray')
plt.colorbar()
plt.show()

# %%
layer = tf.keras.layers.MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='SAME')
output = layer(output)

# %%
plt.figure(figsize=(15, 5))
plt.subplot(131)
plt.hist(output.numpy().ravel(), range=[-2,2])
plt.ylim(0, 500)
plt.subplot(132)
plt.title(output.shape)
plt.imshow(output[0, :, :, 0], 'gray')
plt.colorbar()
plt.show()

# %% [markdown]
# ## Classification (Fully Connected, Dense)

# %% [markdown]
# ### Flatten For Dense Layer
# * tf.keras.layers.Flatten()

# %%
tf.keras.layers.Flatten()

# %%
layer = tf.keras.layers.Flatten()
flatten = layer(output)

# %%
flatten.shape
# Out:
# TensorShape([1, 147])

# %%
output.shape
# Out:
# TensorShape([1, 7, 7, 3])

# %%
plt.figure(figsize=(15, 5))
plt.subplot(211)
plt.hist(flatten.numpy().ravel())
plt.subplot(212)
plt.imshow(flatten[:, :100])
plt.show()

# %% [markdown]
# ### Dense Layer
# * tf.keras.layers.Dense

# %%
tf.keras.layers.Dense(32, activation='relu')

# %%
layer = tf.keras.layers.Dense(32, activation='relu')
output = layer(flatten)

# %%
output.shape
# Out:
# TensorShape([1, 32])

# %% [markdown]
# ### DropOut
# * tf.keras.layers.Dropout()

# %%
layer = tf.keras.layers.Dropout(0.7)
output = layer(output)
